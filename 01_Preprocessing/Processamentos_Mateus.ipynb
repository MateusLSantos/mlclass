# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.neighbors import KNeighborsClassifier
import requests

# %%
pd.options.display.max_rows = 300;

# %%
lrn = pd.read_excel("diabetes_dataset0.xlsx")

# %%
tst = pd.read_excel("diabetes_app0.xlsx")

# %%
lrn.round(4)
tst.round(4)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              3      129             64             29      115  26.4
# 1              3      191             68             15      130  30.9
# 2             15      136             70             32      110  37.1
# 3              1      109             60              8      182  25.4
# 4              8      151             78             32      210  42.9
# 5              4      123             80             15      176  32.0
# 6              3      158             70             30      328  35.5
# 7              6      134             80             37      370  46.2
# 8             10      161             68             23      132  25.5
# 9              1       87             68             34       77  37.6
# 10             2      121             70             32       95  39.1
# 11             9      145             88             34      165  30.3
# 12             7       83             78             26       71  29.3
# 13             8      196             76             29      280  37.5
# 14             0      127             80             37      210  36.3
# 15             2      102             86             36      120  45.5
# 16             8      126             88             36      108  38.5
# 17             3      130             78             23       79  28.4
# 18             1       71             48             18       76  20.4
# 19             6      154             78             41      140  46.1
# 20             2       68             62             13       15  20.1
# 21             1      117             88             24      145  34.5
# 22             2      157             74             35      440  39.4
# 23             2      112             68             22       94  34.1
# 24             1      131             64             14      415  23.7
# 25             0      181             88             44      510  43.3
# 26             1       95             74             21       73  25.9
# 27             4      110             76             20      100  28.4
# 28             1      115             70             30       96  34.6
# 29             4      184             78             39      277  37.0
# 30             0      129            110             46      130  67.1
# 31            13      152             90             33       29  26.8
# 32             7      150             66             42      342  34.7
# 33             1       95             82             25      180  35.0
# 34             1       97             66             15      140  23.2
# 35             1      108             60             46      178  35.5
# 36             0      177             60             29      478  34.6
# 37            10      125             70             26      115  31.1
# 38             0       84             64             22       66  35.8
# 39             7      195             70             33      145  25.1
# 40             5      139             80             35      160  31.6
# 41             3      187             70             22      200  36.4
# 42             9      120             72             22       56  20.8
# 43             1       77             56             30       56  33.3
# 44             5      123             74             40       77  34.1
# 45             1       87             78             27       32  34.6
# 46             5      144             82             26      285  32.0
# 47             1      193             50             16      375  25.9
# 48             2       83             65             28       66  36.8
# 49             2      106             64             35      119  30.5
# 50             3      116             74             15      105  26.3
# 51             1      189             60             23      846  30.1
# 52             2      107             74             30      100  33.6
# 53             8      100             74             40      215  39.4
# 54             2      100             54             28      105  37.8
# 55             2      101             58             17      265  24.2
# 56             1      100             74             12       46  19.5
# 57             0      126             86             27      120  27.4
# 58             0      180             78             63       14  59.4
# 59             1      128             88             39      110  36.5
# 60             1      126             56             29      152  28.7
# 61             4       85             58             22       49  27.8
# 62             0      198             66             32      274  41.3
# 63             0       91             68             32      210  39.9
# 64             2       96             68             13       49  21.1
# 65             0       95             85             25       36  37.4
# 66             2      146             76             35      194  38.2
# 67             4       91             70             32       88  33.1
# 68             2       93             64             32      160  38.0
# 69             1      119             86             39      220  45.6
# 70             9      152             78             34      171  34.2
# 71             3      111             90             12       78  28.4
# 72             0      162             76             56      100  53.2
# 73             4      146             85             27      100  28.9
# 74             1      112             80             45      132  34.8
# 75             3      102             44             20       94  30.8
# 76             2      144             58             33      135  31.6
# 77             8      179             72             42      130  32.7
# 78             2      128             78             37      182  43.3
# 79             6      123             72             45      230  33.6
# 80             1      136             74             50      204  37.4
# 81             2      146             70             38      360  28.0
# 82             2      122             52             43      158  36.2
# 83             1      130             70             13      105  25.9
# 84             1       80             74             11       60  30.0
# 85             2       99             60             17      160  36.6
# 86             6      134             70             23      130  35.4
# 87             1       81             72             18       40  26.6
# 88            12      140             82             43      325  39.2
# 89             3      115             66             39      140  38.1
# 90             1       79             80             25       37  25.4
# 91             1       90             62             12       43  27.2
# 92             1       81             74             41       57  46.3
# 93             1      100             72             12       70  25.3
# 94             1      125             70             24      110  24.3
# 95             3      174             58             22      194  32.9
# 96             0      139             62             17      210  22.1
# 97             1      149             68             29      127  29.3
# 98             5      105             72             29      325  36.9
# 99             0       95             64             39      105  44.6
# 100            0       97             64             36      100  36.8
# 101            1      181             78             42      293  40.0
# 102            2      120             76             37      105  39.7
# 103            4       84             90             23       56  39.5
# 104            3      163             70             18      105  31.6
# 105            1      109             38             18      120  23.1
# 106            2      106             56             27      165  29.0
# 107            0       95             80             45       92  36.5
# 108            3      120             70             30      135  42.9
# 109            6       98             58             33      190  34.0
# 110            2       88             74             19       53  29.0
# 111            0      114             80             34      285  44.2
# 112            1       95             66             13       38  19.6
# 113            9      156             86             28      155  34.3
# 114            3      113             50             10       85  29.5
# 115            5      155             84             44      545  38.7
# 116            7      124             70             33      215  25.5
# 117            0      104             64             37       64  33.6
# 118            3       80             82             31       70  34.2
# 119            7       94             64             25       79  33.3
# 120            3       78             50             32       88  31.0
# 121            2      110             74             29      125  32.4
# 122            7      181             84             21      192  35.9
# 123            1       90             62             18       59  25.1
# 124            5       99             54             28       83  34.0
# 125           10      101             76             48      180  32.9
# 126            1       82             64             13       95  21.2
# 127            2       75             64             24       55  29.7
# 128            4      116             72             12       87  22.1
# 129            0      152             82             39      272  41.5
# 130            0       74             52             10       36  27.8
# 131            9      124             70             33      402  35.4
# 132            1      119             44             47       63  35.5
# 133            3       84             68             30      106  31.9
# 134            8      181             68             36      495  30.1
# 135            1      116             78             29      180  36.1
# 136            1      140             74             26      180  24.1
# 137            3      111             58             31       44  29.5
# 138            2       94             68             18       76  26.0
# 139            8      124             76             24      600  28.7
# 140           11      120             80             37      150  42.3
# 141            4      125             70             18      122  28.9
# 142            5      166             72             19      175  25.8
# 143            6      144             72             27      228  33.9
# 144            2      108             52             26       63  32.5
# 145            2      122             76             27      200  35.9
# 146            1      109             56             21      135  25.2
# 147            1       95             60             18       58  23.9
# 148            2       56             56             28       45  24.2
# 149            5      108             72             43       75  36.1
# 150            1      119             54             13       50  22.3
# 151            1      111             62             13      182  24.0
# 152            2      105             58             40       94  34.9
# 153            1      164             82             43       67  32.8
# 154            1       89             66             23       94  28.1
# 155            4      144             58             28      140  29.5
# 156           10      129             76             28      122  35.9
# 157            0      180             90             26       90  36.5
# 158            2      142             82             18       64  24.7
# 159            3      129             92             49      155  36.4
# 160            0      104             64             23      116  27.8
# 161            7      142             60             33      190  28.8
# 162            1      109             58             18      116  28.5
# 163            1      125             50             40      167  33.3
# 164            4       90             88             47       54  37.7
# 165            0      117             80             31       53  45.2
# 166            8      155             62             26      495  34.0
# 167            4      129             60             12      231  27.5
# 168            1      122             90             51      220  49.7
# 169            3      103             72             30      152  27.6
# 170            9      171            110             24      240  45.4
# 171            0      100             88             60      110  46.8
# 172            2       84             50             23       76  30.4
# 173            2       83             66             23       50  32.2
# 174            1       92             62             25       41  19.5
# 175            3       99             62             19       74  21.8
# 176            2      108             62             32       56  25.2
# 177            0      134             58             20      291  26.4
# 178            0      117             66             31      188  30.8
# 179            5      187             76             27      207  43.6
# 180            8      167            106             46      231  37.6
# 181            0      173             78             32      265  46.5
# 182            3       83             58             31       18  34.3
# 183            1       97             64             19       82  18.2
# 184            1       89             24             19       25  27.8
# 185            4      103             60             33      192  24.0
# 186            0      102             64             46       78  40.6
# 187            3      100             68             23       81  31.6
# 188            0       98             82             15       84  25.2
# 189            2      141             58             34      128  25.4
# 190            7      168             88             42      321  38.2
# 191            3      180             64             25       70  34.0
# 192            3       99             54             19       86  25.6
# 193            8      176             90             34      300  33.7
# 194            0       84             82             31      125  38.2
# 195            3       89             74             16       85  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.219   28
# 1                       0.299   34
# 2                       0.153   43
# 3                       0.947   21
# 4                       0.516   36
# 5                       0.443   34
# 6                       0.344   35
# 7                       0.238   46
# 8                       0.326   47
# 9                       0.401   24
# 10                      0.886   23
# 11                      0.771   53
# 12                      0.767   36
# 13                      0.605   57
# 14                      0.804   23
# 15                      0.127   23
# 16                      0.349   49
# 17                      0.323   34
# 18                      0.323   22
# 19                      0.571   27
# 20                      0.257   23
# 21                      0.403   40
# 22                      0.134   30
# 23                      0.315   26
# 24                      0.389   21
# 25                      0.222   26
# 26                      0.673   36
# 27                      0.118   27
# 28                      0.529   32
# 29                      0.264   31
# 30                      0.319   26
# 31                      0.731   43
# 32                      0.718   42
# 33                      0.233   43
# 34                      0.487   22
# 35                      0.415   24
# 36                      1.072   21
# 37                      0.205   41
# 38                      0.545   21
# 39                      0.163   55
# 40                      0.361   25
# 41                      0.408   36
# 42                      0.733   48
# 43                      1.251   24
# 44                      0.269   28
# 45                      0.101   22
# 46                      0.452   58
# 47                      0.655   24
# 48                      0.629   24
# 49                      1.400   34
# 50                      0.107   24
# 51                      0.398   59
# 52                      0.404   23
# 53                      0.661   43
# 54                      0.498   24
# 55                      0.614   23
# 56                      0.149   28
# 57                      0.515   21
# 58                      2.420   25
# 59                      1.057   37
# 60                      0.801   21
# 61                      0.306   28
# 62                      0.502   28
# 63                      0.381   25
# 64                      0.647   26
# 65                      0.247   24
# 66                      0.329   29
# 67                      0.446   22
# 68                      0.674   23
# 69                      0.808   29
# 70                      0.893   33
# 71                      0.495   29
# 72                      0.759   25
# 73                      0.189   27
# 74                      0.217   24
# 75                      0.400   26
# 76                      0.422   25
# 77                      0.719   36
# 78                      1.224   31
# 79                      0.733   34
# 80                      0.399   24
# 81                      0.337   29
# 82                      0.816   28
# 83                      0.472   22
# 84                      0.527   22
# 85                      0.453   21
# 86                      0.542   29
# 87                      0.283   24
# 88                      0.528   58
# 89                      0.150   28
# 90                      0.583   22
# 91                      0.580   24
# 92                      1.096   32
# 93                      0.658   28
# 94                      0.221   25
# 95                      0.593   36
# 96                      0.207   21
# 97                      0.349   42
# 98                      0.159   28
# 99                      0.366   22
# 100                     0.600   25
# 101                     1.258   22
# 102                     0.215   29
# 103                     0.159   25
# 104                     0.268   28
# 105                     0.407   26
# 106                     0.426   22
# 107                     0.330   26
# 108                     0.452   30
# 109                     0.430   43
# 110                     0.229   22
# 111                     0.167   27
# 112                     0.334   25
# 113                     1.189   42
# 114                     0.626   25
# 115                     0.619   34
# 116                     0.161   37
# 117                     0.510   22
# 118                     1.292   27
# 119                     0.738   41
# 120                     0.248   26
# 121                     0.698   27
# 122                     0.586   51
# 123                     1.268   25
# 124                     0.499   30
# 125                     0.171   63
# 126                     0.415   23
# 127                     0.370   33
# 128                     0.463   37
# 129                     0.270   27
# 130                     0.269   22
# 131                     0.282   34
# 132                     0.280   25
# 133                     0.591   25
# 134                     0.615   60
# 135                     0.496   25
# 136                     0.828   23
# 137                     0.430   22
# 138                     0.561   21
# 139                     0.687   52
# 140                     0.785   48
# 141                     1.144   45
# 142                     0.587   51
# 143                     0.255   40
# 144                     0.318   22
# 145                     0.483   26
# 146                     0.833   23
# 147                     0.260   22
# 148                     0.332   22
# 149                     0.263   33
# 150                     0.205   24
# 151                     0.138   23
# 152                     0.225   25
# 153                     0.341   50
# 154                     0.167   21
# 155                     0.287   37
# 156                     0.280   39
# 157                     0.314   35
# 158                     0.761   21
# 159                     0.968   32
# 160                     0.454   23
# 161                     0.687   61
# 162                     0.219   22
# 163                     0.962   28
# 164                     0.362   29
# 165                     0.089   24
# 166                     0.543   46
# 167                     0.527   31
# 168                     0.325   31
# 169                     0.730   27
# 170                     0.721   54
# 171                     0.962   31
# 172                     0.968   21
# 173                     0.497   22
# 174                     0.482   25
# 175                     0.279   26
# 176                     0.128   21
# 177                     0.352   21
# 178                     0.493   22
# 179                     1.034   53
# 180                     0.165   43
# 181                     1.159   58
# 182                     0.336   25
# 183                     0.299   21
# 184                     0.559   21
# 185                     0.966   33
# 186                     0.496   21
# 187                     0.949   28
# 188                     0.299   22
# 189                     0.699   24
# 190                     0.787   40
# 191                     0.271   26
# 192                     0.154   24
# 193                     0.467   58
# 194                     0.233   23
# 195                     0.551   38

# %% [markdown]
# <h1> Remoção de SkinThickness e Insulin </h1>

# %% [markdown]
# #Limpando dataset
# n = 0;
# for val in lrn['SkinThickness']:
#     lrn.at[n, 'SkinThickness'] = 0;
#     n = n+1;
#
# n = 0;
# for val in lrn['Insulin']:
#     lrn.at[n, 'Insulin'] = 0;
#     n = n+1;
#
# #Limpando teste
# n = 0;
# for val in tst['SkinThickness']:
#     tst.at[n, 'SkinThickness'] = 0;
#     n = n+1;
#
# n = 0;
# for val in tst['Insulin']:
#     tst.at[n, 'Insulin'] = 0;
#     n = n+1;

# %% [markdown]
# <h1> Removendo os sem-glicose e outliers </h1>

# %%
n = 0;
for val in lrn['Glucose']:
    if np.isnan(val):
        #print("IsNan: ", n)
        lrn = lrn.drop(index = n);
    n = n+1;

lrn.index = range(len(lrn))

# %%
n = 0;
for val in lrn['SkinThickness']:
    if val > 80:
        #print("IsNan: ", n)
        lrn = lrn.drop(index = n);
    n = n+1;

lrn.index = range(len(lrn))

# %% [markdown]
# <h1> Preenchendo com média/mediana </h1>

# %%
#Calculando as médias
n = 0; #Número de membros
s = 0; #Soma
for val in lrn['BMI']:
    if not np.isnan(val):
        s = s + val;
        n = n + 1;

meanBMI = round(s/n, 1);

n = 0; #Número de membros
s = 0; #Soma
for val in lrn['BloodPressure']:
    if not np.isnan(val):
        s = s + val;
        n = n + 1;

meanBP = round(s/n);

n = 0; #Número de membros
s = 0; #Soma
for val in lrn['SkinThickness']:
    if not np.isnan(val):
        s = s + val;
        n = n + 1;

meanST = round(s/n);

n = 0; #Número de membros
s = 0; #Soma
for val in lrn['Insulin']:
    if not np.isnan(val):
        s = s + val;
        n = n + 1;

meanIns = round(s/n);


#Ideia: ao invés de usar apenas uma média, poderíamos usar as médias estratificadas, uma para cada grupo, depois.

# %%
#Atribuindo as médias às células vazias

n = 0;
for val in lrn['BMI']:
    if np.isnan(val):
        lrn.at[n, 'BMI'] = meanBMI;
        #lrn.at[n, 'BMI'] = 0; #Preencher com 0 ao invés da média
    n = n + 1;

n = 0;
for val in lrn['BloodPressure']:
    if np.isnan(val):
        lrn.at[n, 'BloodPressure'] = meanBP;
        #lrn.at[n, 'BloodPressure'] = 0; #Preencher com 0 ao invés da média
    n = n + 1;
    
n = 0;

# %%
for val in lrn['SkinThickness']:
    if np.isnan(val):
        lrn.at[n, 'SkinThickness'] = meanST;
        #lrn.at[n, 'SkinThickness'] = 0; #Preencher com 0 ao invés da média
    n = n + 1;
    
n = 0;
for val in lrn['Insulin']:
    if np.isnan(val):
        lrn.at[n, 'Insulin'] = meanIns;
        #lrn.at[n, 'BMI'] = 0; #Preencher com 0 ao invés da média
    n = n + 1;

# %% [markdown]
# <h1> Preenchendo com média/mediana Insulin e SkinThickness por grupo </h1>

# %% [markdown]
# #Calculando as médias
# n = 0; #Contagem de iterações;
# n0 = 0; #Número de membros saudáveis
# s0 = 0; #Soma saudáveis
# n1 = 0; #Número de membros doentes
# s1 = 0; #Soma doentes
#
#
# for val in lrn['Insulin']:
#     if not np.isnan(val):
#         if lrn.loc[n, 'Outcome'] == 0:
#             s0 = s0 + val;
#             n0 = n0 + 1;
#         else:
#             s1 = s1 + val;
#             n1 = n1 + 1;
#     n = n+1;
#
# meanI0 = round(s0/n0, 1);
# meanI1 = round(s1/n1, 1);
# print(meanI0);
# print(meanI1);
#
# n = 0; #Contagem de iterações;
# n0 = 0; #Número de membros saudáveis
# s0 = 0; #Soma saudáveis
# n1 = 0; #Número de membros doentes
# s1 = 0; #Soma doentes
#
#
# for val in lrn['SkinThickness']:
#     if not np.isnan(val):
#         if lrn.loc[n, 'Outcome'] == 0:
#             s0 = s0 + val;
#             n0 = n0 + 1;
#         else:
#             s1 = s1 + val;
#             n1 = n1 + 1;
#     n = n+1;
#
# meanST0 = round(s0/n0);
# meanST1 = round(s1/n1);
# print(meanST0);
# print(meanST1);

# %% [markdown]
# #Atribuindo as médias às células vazias
#
# n = 0;
# for val in lrn['Insulin']:
#     if np.isnan(val):
#         if lrn.loc[n, 'Outcome'] == 0:
#             lrn.loc[n, 'Insulin'] = meanI0;
#         else:
#             lrn.loc[n, 'Insulin'] = meanI1;
#     n = n + 1;
#
# n = 0;
# for val in lrn['SkinThickness']:
#     if np.isnan(val):
#         if lrn.loc[n, 'Outcome'] == 0:
#             lrn.loc[n, 'SkinThickness'] = meanST0;
#         else:
#             lrn.loc[n, 'SkinThickness'] = meanST1;
#     n = n + 1;

# %% [markdown]
# <h1> Normalização min-máx </h1>

# %%
lrn2 = lrn.copy();
cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
for col in cols:
    ma = lrn2[col].max();
    mi = lrn2[col].min();
    n = 0;
    for val in lrn[col]:
        new_val = round((val-mi)/(ma-mi), 10)
        lrn.loc[n, col] = new_val
        n = n + 1;

# %%
tst2 = tst.copy();
for col in cols:
    ma = lrn2[col].max();
    mi = lrn2[col].min();
    n = 0;
    for val in tst[col]:
        new_val = round((val-mi)/(ma-mi), 10)
        tst.loc[n, col] = new_val
        n = n + 1;
    
normalized_tst = tst.copy();
normalized_lrn = lrn.copy();

# %% [markdown]
# <h1> Normalização 0-máx </h1>

# %% [markdown]
# lrn2 = lrn.copy();
# cols = ['Pregnancies','Glucose', 'BloodPressure', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# for col in cols:
#     ma = lrn2[col].max();
#     n = 0;
#     for val in lrn[col]:
#         new_val = round(val/ma, 6)
#         lrn.loc[n, col] = new_val
#         n = n + 1;

# %% [markdown]
# tst2 = tst.copy();
# for col in cols:
#     ma = lrn2[col].max();
#     n = 0;
#     for val in tst[col]:
#         new_val = round(val/ma, 6)
#         tst.loc[n, col] = new_val
#         n = n + 1;

# %% [markdown]
# <h1> Atribuindo Pesos </h1>

# %%
#Pesos por correlação: [0.185400, 0.480425, 0.099409, 0.252870, 0.274332, 0.308132, 0.171984, 0.171850]
#Melhor: weight_list = [70, 3200, 0, 80, 80, 140, 50, 90]
#['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

#Pregnancies: 58.16%
#Glucose: 73.4%
#BloodPressure: 46.42%
#SkinThickness: 60.71%
#Insulin: 63%
#BMI: 62.24%
#DiabetesPedigreeFunction: 52.04%
#Age: 71.93%

# %%
weight_list = [8, 26, 12, 10, 10, 10, 10, 10]
#melhor: weight_list = [8, 26, 12, 10, 10, 10, 10, 10]
lrn = normalized_lrn.copy();
tst = normalized_tst.copy();
n = 0;
for col in cols:
    lrn[col] = lrn[col]*weight_list[n]
    tst[col] = tst[col]*weight_list[n]
    n=n+1; 
lrn.to_excel("diabetes_dataset.xlsx");
tst.to_excel("diabetes_app.xlsx");
print('\n - Lendo o arquivo com o dataset sobre diabetes')
data = pd.read_excel('diabetes_dataset.xlsx')
print(' - Criando X e y para o algoritmo de aprendizagem a partir do arquivo diabetes_dataset')
feature_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
X = data[feature_cols]
y = data.Outcome
print(' - Criando modelo preditivo')
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, y)
print(' - Aplicando modelo e enviando para o servidor')
data_app = pd.read_excel('diabetes_app.xlsx')
y_pred = neigh.predict(data_app)
URL = "https://aydanomachado.com/mlclass/01_Preprocessing.php"
DEV_KEY = "Ponte de Safena"
data = {'dev_key':DEV_KEY, 'predictions':pd.Series(y_pred).to_json(orient='values')}
r = requests.post(url = URL, data = data)
pastebin_url = r.text
print(" - Resposta do servidor:\n", r.text, "\n")
# Out:
#  - Lendo o arquivo com o dataset sobre diabetes
#  - Criando X e y para o algoritmo de aprendizagem a partir do arquivo diabetes_dataset
#  - Criando modelo preditivo
#  - Aplicando modelo e enviando para o servidor
#  - Resposta do servidor:
#  {"status":"success","dev_key":"Ponte de Safena","accuracy":0.80102040816327,"old_accuracy":0.80102040816327}

# %% [markdown]
# ma = max(weight_list.copy())
# mi = min(weight_list.copy())
# n = 0;
# for num in weight_list:
#     new = ((num-mi)/(ma-mi))*10
#     weight_list[n] = new;
#     n = n+1;
# print(weight_list)

# %% [markdown]
# n = 0;
# for col in cols:
#     lrn[col] = lrn[col]*weight_list[n]
#     tst[col] = tst[col]*weight_list[n]
#     n=n+1;

# %% [markdown]
# <h1> Salvando... </h1>

# %% [markdown]
# lrn.to_excel("diabetes_dataset.xlsx");
# tst.to_excel("diabetes_app.xlsx");

# %% [markdown]
# print('\n - Lendo o arquivo com o dataset sobre diabetes')
# data = pd.read_excel('diabetes_dataset.xlsx')
#
# # Criando X and y par ao algorítmo de aprendizagem de máquina.\
# print(' - Criando X e y para o algoritmo de aprendizagem a partir do arquivo diabetes_dataset')
# # Caso queira modificar as colunas consideradas basta algera o array a seguir.
# feature_cols = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#                 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# X = data[feature_cols]
# y = data.Outcome
#
# # Ciando o modelo preditivo para a base trabalhada
# print(' - Criando modelo preditivo')
# neigh = KNeighborsClassifier(n_neighbors=3)
# neigh.fit(X, y)
#
# #realizando previsões com o arquivo de
# print(' - Aplicando modelo e enviando para o servidor')
# data_app = pd.read_excel('diabetes_app.xlsx')
# y_pred = neigh.predict(data_app)
#
# # Enviando previsões realizadas com o modelo para o servidor
# URL = "https://aydanomachado.com/mlclass/01_Preprocessing.php"
#
# #TODO Substituir pela sua chave aqui
# DEV_KEY = "Ponte de Safena"
#
# # json para ser enviado para o servidor
# data = {'dev_key':DEV_KEY,
#         'predictions':pd.Series(y_pred).to_json(orient='values')}
#
# # Enviando requisição e salvando o objeto resposta
# r = requests.post(url = URL, data = data)
#
# # Extraindo e imprimindo o texto da resposta
# pastebin_url = r.text
# print(" - Resposta do servidor:\n", r.text, "\n")
